# %%
Solve[y'[a]+y[a]=5,y[a],a]
# Out:
# Set::write: Tag Plus in y[a] + y'[a] is Protected.
# Solve::bdomv: Warning: a is not a valid domain specification. Assuming it is a variable to eliminate.
# Solve::naqs: 5 is not a quantified system of equations and inequalities.
# Solve[5, y[a], a]

# %%
DSolve[y'[x]+y[x]==a*Sin[x],y[x],x]
# Out:
#           C[1]   a (-Cos[x] + Sin[x])
# {{y[x] -> ---- + --------------------}}
#             x             2
#            E

# %%
DSolve[{y''[x]==x},y[x],x]
DSolve[{y'[x]+y[x]==a*Sin[x]},y[x],x]
# Out:
#            3
#           x
# {{y[x] -> -- + C[1] + x C[2]}}
#           6
#           C[1]   a (-Cos[x] + Sin[x])
# {{y[x] -> ---- + --------------------}}
#             x             2
#            E

# %%
DSolve[y''[x]+y[x]^2==1,y[x],x]
# Out:
#                 2/3  1/3                 1  1/3                    2/3  1/3
# {{y[x] -> -((-1)    6    WeierstrassP[(-(-))    (x + C[1]), {2 (-1)    6   , C[2]}])}}
#                                          6

# %%
f = cs*cs * T0*T0 / (mv*mv) * k*k /(H0*H0 * Omega_M)
b = delta0/ a0
# Out:
#      2  2   2
#    cs  k  T0
# -----------------
#   2   2
# H0  mv  (Omega_M)
# delta0
# ------
#   a0

# %%
Simplify[DSolve[{a^2*y''[a]+3/2 * a * y'[a]+f/(a^2)*y[a]==3/2*b},y[a],{a}]]
# Out:
# {{y[a] -> Power[E, Inactive[Integrate][(2 K[1])/3 -
#
#                2  2   2       2   2     3
# >         (2 cs  k  T0 )/(3 H0  mv  K[1]  (Omega_M)), {K[1], 1, a}]]
#
# >      (C[1] + Inactive[Integrate][delta0 /
#
# >          (a0 Power[E, Inactive[Integrate][(2 K[1])/3 -
#
#                      2  2   2       2   2     3
# >               (2 cs  k  T0 )/(3 H0  mv  K[1]  (Omega_M)), {K[1], 1, K[2]}]] K[2]),
#
# >         {K[2], 1, a}])}}

# %%
Integrate[delta0/a0 * 1/x * exp(1/3 * beta * (1-1/(x*x)))*exp(1/3*(1-x*x)),x]
# Out:
#                                   2
#                     2    1  1    x
#      beta delta0 exp  (-(-) -- + -- - 2 Log[x])
#                          2   2   2
#   1                         x
# -(-) ------------------------------------------
#   9                      a0

# %%
Integrate[delta0/a0 * 1/x * exp(1/3 * beta * (1-1/(x*x))+1/3*(1-x*x)),x]
# Out:
#                               2
#                    1  beta   x
#      delta0 exp (-(-) ---- + -- - Log[x] - beta Log[x])
#                    2    2    2
#   1                    x
# -(-) --------------------------------------------------
#   3                          a0

# %%
exp[Ln[x]]
# Out:
# exp[Ln[x]]
